# %% [markdown]
# # 🚌 Análise Especial: Mobilidade Urbana e Vulnerabilidade
# ### Foco: Ônibus (Transporte Coletivo), Bicicletas, Via Pública e Celulares
#
# Este notebook cruza as bases específicas de roubos e furtos ocorridos durante o deslocamento do cidadão. Ele integra as bases `roubo via publica 2021 a 2024.csv`, `(BIKE,CELULAR,VEICULO)2025 roub e furt.csv`, `furtos_2024.csv` e `roubos_2024.csv` para extrair inteligência sobre a mancha criminal na mobilidade.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %% [markdown]
# ## INSIGHT 1: O Risco do Deslocamento (Ponto de Ônibus vs Via Pública)
# A maior parte dos roubos a transeuntes (Via Pública) ocorre enquanto a vítima aguarda o transporte ou se desloca a pé. Vamos cruzar a base de Celulares com a Via Pública para entender o peso real dessa modalidade.

# %%
def cruzar_celular_via_publica_onibus(df_via_publica, df_celular):
    """
    Cruza as ocorrências de Via Pública com Roubos de Celular para provar a hipótese de que 
    o alvo principal nas ruas/pontos de ônibus é o smartphone.
    """
    # Exemplo de lógica para o Streamlit:
    # 1. Agrupar ambas as bases por Município e Mês
    # 2. Calcular o percentual: (Roubos de Celular / Roubos em Via Pública) * 100
    # fig = go.Figure()
    # fig.add_trace(go.Bar(name='Total Via Pública (Inclui Ônibus/Rua)', x=df_merge['Município'], y=df_merge['Total_Via_Publica']))
    # fig.add_trace(go.Bar(name='Destes, eram Celulares', x=df_merge['Município'], y=df_merge['Total_Celulares']))
    # fig.update_layout(barmode='overlay', title='Taxa de Roubo de Celulares em Pontos/Via Pública')
    # return fig
    pass

# %% [markdown]
# ## INSIGHT 2: A Explosão do Roubo de Bikes vs Veículos Automotores
# A bicicleta se tornou um modal de transporte caro e de fácil revenda. Usando a base `(BIKE,CELULAR,VEICULO)2025 roub e furt.csv`, vamos comparar o risco de quem anda de Bike x Carro/Moto.

# %%
def comparar_bike_veiculo_2025(df_bike_cel_veic_2025):
    """
    Extrai especificamente a fatia de 'Bicicletas' e compara com 'Veículos' 
    para identificar a mudança no padrão de interesse do crime.
    """
    # df_veiculos_mobilidade = df_bike_cel_veic_2025[df_bike_cel_veic_2025['Categoria'].isin(['BIKE', 'VEICULO'])]
    # fig = px.pie(df_veiculos_mobilidade, values='Quantidade', names='Categoria', 
    #              hole=0.4, title='Proporção de Roubos a Modais de Transporte em 2025')
    # fig.update_traces(textposition='inside', textinfo='percent+label')
    # return fig
    pass

# %% [markdown]
# ## INSIGHT 3: Matriz de Vulnerabilidade (Matriz Correlação)
# Cruzando os totais absolutos de `furtos_2024.csv` e `roubos_2024.csv`.
# Qual a probabilidade de um município com alto roubo a ônibus/via pública também ter alto roubo de Bikes?
# Isso prova a tese de "Degradação do Espaço Público" (Teoria das Janelas Quebradas).

# %%
def matriz_correlacao_mobilidade(df_furtos, df_roubos):
    """
    Cria um heatmap de correlação provando se crimes de via pública atraem furtos de bike.
    """
    # df_unido = pd.merge(df_furtos, df_roubos, on='Município')
    # cols_interesse = ['Roubo_Via_Publica', 'Furto_Bicicleta', 'Roubo_Transporte_Coletivo', 'Furto_Celular']
    # correlacao = df_unido[cols_interesse].corr()
    # fig = px.imshow(correlacao, text_auto=True, aspect="auto", 
    #                 title='Mapa de Correlação (Teoria das Janelas Quebradas nas Vias)')
    # return fig
    pass
